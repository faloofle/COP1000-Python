# %%
#variables
first_name = "Aiden"
age = 19
distance_to_home = 9.5
is_alive = True

#printing variables
print(first_name)
print(age)
print(distance_to_home)
print(is_alive)
print("\n")

#types
print(type(first_name))
print(type(age))
print(type(distance_to_home))
print(type(is_alive))
print("\n")

#changing variable
score=75
print(score)
score=90
print(score)
print("\n")

#practicing math
number1=50
number2=5
print(number1+number2)
print(number1-number2)
print(number1*number2)
print(number1/number2)

#f string
academic_interest= "computer science"
last_name= "Barry"
print(f"My name is {first_name} {last_name} and I am interested in {academic_interest}. \n")

#student record
course="COP1000"
current_grade= 100.0
completed= 3
is_enrolled= True
print(f"Student Record \n Name: {first_name}{last_name} \n Course: {course} \n Current Grade: {current_grade} \n Completed Assignments: {completed} \n Enrolled: {is_enrolled} \n")

#
# Out:
# Aiden
# 19
# 9.5
# True
#
#
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
#
#
# 75
# 90
#
#
# 55
# 45
# 250
# 10.0
# My name is Aiden Barry and I am interested in computer science.
#
# Student Record
#  Name: AidenBarry
#  Course: COP1000
#  Current Grade: 100.0
#  Completed Assignments: 3
#  Enrolled: True
